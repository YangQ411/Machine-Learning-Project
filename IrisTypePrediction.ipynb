# %% [markdown]
# ## **1. Import libraries**

# %%
import numpy as np # for calculating 
import pandas as pd # for visualization and contruction of dadaframe
import matplotlib as plt # for plotting

# %% [markdown]
# ## **2. loading dataset**

# %%
dataset = pd.read_csv('iris.csv')
dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### The types of output

# %%
dataset.Species.value_counts(normalize=False)
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ## **3. Split dataset into train and test**

# %%
from sklearn.model_selection import train_test_split

X = dataset.drop(['Species'],axis=1)
Y = dataset['Species']  

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, 
                                                    test_size=0.4, 
                                                    random_state=1) 
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((90, 5), (60, 5), (90,), (60,))

# %% [markdown]
# ## **5. Train our dataset**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Clf = RandomForestClassifier(n_jobs = 2, random_state = 0)
Clf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(n_jobs=2, random_state=0)

# %% [markdown]
# ## **6. Make Prediction**

# %%
y_pred = Clf.predict(X_test)

# %% [markdown]
# ## **7. Evaluate our Model**

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

print('Accuracy score of Random Froest: ', accuracy_score(Y_test, y_pred)*100)
print('f1 score of Random Froest: ', f1_score(Y_test, y_pred, average='weighted'))
# Out:
# Accuracy score of Random Froest:  100.0
# f1 score of Random Froest:  1.0

# %%
pd.crosstab(Y_test, y_pred, rownames=['Actual Species'], colnames=['Predicted Species'])
# Out:
# Predicted Species  Iris-setosa  Iris-versicolor  Iris-virginica
# Actual Species
# Iris-setosa                 19                0               0
# Iris-versicolor              0               21               0
# Iris-virginica               0                0              20
